# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/sumathi16/Machine-Learning-with-Python/master/data/Student%20Data%20ML%20Jan%20(Responses)%20-%20Form%20responses%201.csv')
data.info()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1289             body = _encode(body, 'body')
# -> 1290         self.endheaders(body, encode_chunked=encode_chunked)
#    1291
#
# ...

# %%
data.Qualification
# Out:
# 0     B.Tech
# 1         PG
# 2         PG
# 3         PG
# 4      BTech
# 5     B.Tech
# 6     B.Tech
# 7     B.Tech
# 8       M.sc
# 9         PG
# 10       Msc
# 11       MCA
# 12    B.Tech
# 13    B.TECH
# 14       MSc
# 15    B.Tech
# 16    B.Tech
# 17    B.tech
# 18    degree
# 19    Degree
# 20       MCA
# 21      M.Sc
# 22    B.TECH
# 23    B-tech
# 24    B.TECH
# 25       B.E
# Name: Qualification, dtype: object

# %%
data.loc[0:,'Qualification']
# Out:
# 0     B.Tech
# 1         PG
# 2         PG
# 3         PG
# 4      BTech
# 5     B.Tech
# 6     B.Tech
# 7     B.Tech
# 8       M.sc
# 9         PG
# 10       Msc
# 11       MCA
# 12    B.Tech
# 13    B.TECH
# 14       MSc
# 15    B.Tech
# 16    B.Tech
# 17    B.tech
# 18    degree
# 19    Degree
# 20       MCA
# 21      M.Sc
# 22    B.TECH
# 23    B-tech
# 24    B.TECH
# 25       B.E
# Name: Qualification, dtype: object

# %%
data['Qualification']
# Out:
# 0     B.Tech
# 1         PG
# 2         PG
# 3         PG
# 4      BTech
# 5     B.Tech
# 6     B.Tech
# 7     B.Tech
# 8       M.sc
# 9         PG
# 10       Msc
# 11       MCA
# 12    B.Tech
# 13    B.TECH
# 14       MSc
# 15    B.Tech
# 16    B.Tech
# 17    B.tech
# 18    degree
# 19    Degree
# 20       MCA
# 21      M.Sc
# 22    B.TECH
# 23    B-tech
# 24    B.TECH
# 25       B.E
# Name: Qualification, dtype: object

# %%
data[data.Qualification=='B.Tech']
# Out:
#               Timestamp                   Name  \
# 0   30/01/2020 15:00:07          Sai Naga Raju
# 5   30/01/2020 15:00:28          M.Geethanjali
# 6   30/01/2020 15:00:33              M.Nikhita
# 7   30/01/2020 15:00:37       DASARI PAVAN SAI
# 12  30/01/2020 15:00:45  Thatavarti kavya sree
# 15  30/01/2020 15:01:24         Devendra Kumar
# 16  30/01/2020 15:01:35                M.Ramya
#
#                               MailId                  Branch Qualification  \
# 0   sainagarajusakhamuri99@gmail.com                      IT        B.Tech
# 5            geethamuppuri@gmail.com                     CSE        B.Tech
# 6             muvvanikhita@gmail.com                     CSE        B.Tech
# 7           pavandasari226@gmail.com  Information Technology        B.Tech
# 12         kavyathatavarti@gmail.com                      IT        B.Tech
# 15          devendra108148@gmail.com                     ECE        B.Tech
# ...

# %%
data['MailId'][data.Qualification=='B.Tech']
# Out:
# 0     sainagarajusakhamuri99@gmail.com
# 5              geethamuppuri@gmail.com
# 6               muvvanikhita@gmail.com
# 7             pavandasari226@gmail.com
# 12           kavyathatavarti@gmail.com
# 15            devendra108148@gmail.com
# 16          ramya.marripoodi@gmail.com
# Name: MailId, dtype: object

# %%
data['RollNumber'][data.Branch == 'Data Science']
# Out:
# 8     121822502015
# 14    121822502018
# 21    121822502016
# Name: RollNumber, dtype: object

# %%
data['RollNumber'][data.Branch == 'I.T']
# Out:
# 22    161FA07012
# 24    161FA07025
# Name: RollNumber, dtype: object

# %%
import re
for i in data["Branch"]:
    if re.search("IT" or "I.T" or "Information Technology" ,i):
        print(i)
# Out:
# IT
# IT

# %%
((data.Branch=="IT")|(data.Branch=="I.T")).sum()
# Out:
# 4

# %%
data.Qualification[data.Qualification=='B.tech'] = 'B.Tech'

# %%
data.Qualification

# %%
data.set_index('RollNumber',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-7e1b34ff1e19> in <module>
# ----> 1 data.set_index('RollNumber',inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['RollNumber'] are in the columns"

# %%
data
# Out:
#                         Timestamp                       Name  \
# RollNumber
# 161FA07039    30/01/2020 15:00:07              Sai Naga Raju
# 121722501019  30/01/2020 15:00:20                   R deepak
# 121722501015  30/01/2020 15:00:23              P K CHAITANYA
# 121722501002  30/01/2020 15:00:25                 B SRIKANTH
# 161fa04079    30/01/2020 15:00:28           Himaja cherukuri
# 161FA04180    30/01/2020 15:00:28              M.Geethanjali
# 161FA04106    30/01/2020 15:00:33                  M.Nikhita
# 161FA07042    30/01/2020 15:00:37           DASARI PAVAN SAI
# 121822502015  30/01/2020 15:00:39              B Jagan Mohan
# 121722501011  30/01/2020 15:00:41          k.parameswara rao
# 121822502017  30/01/2020 15:00:43           B.Ravindra kumar
# 121722501026  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 161FA07050    30/01/2020 15:00:45      Thatavarti kavya sree
# 161FA07035    30/01/2020 15:01:10               Harish Bandi
# ...

# %%
data.sort_values('Qualification')
# Out:
#                         Timestamp                       Name  \
# RollNumber
# 133J1A0150    30/01/2020 15:02:59                   vikram S
# 245112769310  30/01/2020 15:07:38         SAIKUMAR MANIKONDA
# 161FA07012    30/01/2020 15:02:49  JAYA NAVEEN KUMAR DUPPATI
# 161FA07035    30/01/2020 15:01:10               Harish Bandi
# 161FA07025    30/01/2020 15:04:10            SAI TEJA JALADI
# 161FA07049    30/01/2020 15:01:49            T.V.Naga Jyothi
# 161FA07002    30/01/2020 15:01:35                    M.Ramya
# 14F41A0461    30/01/2020 15:01:24             Devendra Kumar
# 161FA07039    30/01/2020 15:00:07              Sai Naga Raju
# 161FA07050    30/01/2020 15:00:45      Thatavarti kavya sree
# 161FA07042    30/01/2020 15:00:37           DASARI PAVAN SAI
# 161FA04106    30/01/2020 15:00:33                  M.Nikhita
# 161FA04180    30/01/2020 15:00:28              M.Geethanjali
# 161fa04079    30/01/2020 15:00:28           Himaja cherukuri
# ...

# %%
college = pd.read_csv('college.csv')
college
# Out:
#      RollNumber College  Year
# 0    161FA07035  vignan  2020
# 1  121822502015    MVSR  2016
# 2    14F41A0461     ASN  2018
# 3    161FA07012  vignan  2020

# %%
pd.merge(data,college,how='left')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-44-0eae03edd5df> in <module>
# ----> 1 pd.merge(data,college,how='left')
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     617             warnings.warn(msg, UserWarning)
#     618
# --> 619         self._validate_specification()
#     620
#     621         # note this function has side effects
#
# ...

# %%
## data,college
- inner - Student availble in both dataframes(intersection)
- outer - student who are there in atleast one dataframe(union)-->27
- left - RollNumber availble in Data --->26
- Right - Roll Number availble in college

# %% [markdown]
# Different column names in two dataframes
# college - 'Roll Number'
# data- 'Roll Number'

# %%
college = pd.read_csv('college.csv')
college.columns
# Out:
# Index(['Roll Number', 'College', 'Year'], dtype='object')

# %%
data.columns
# Out:
# Index(['Timestamp', 'Name', 'MailId', 'Branch', 'Qualification'], dtype='object')

# %%
college
# Out:
#     Roll Number College  Year
# 0    161FA07035  vignan  2020
# 1  121822502015    MVSR  2016
# 2    14F41A0461     ASN  2018
# 3    161FA07012  vignan  2020

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left, right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
#     Merge DataFrame or named Series objects with a database-style join.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#
#     Parameters
#     ----------
#     left : DataFrame
#     right : DataFrame or named Series
#         Object to merge with.
#     how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#         Type of merge to be performed.
#
#         * left: use only keys from left frame, similar to a SQL left outer join;
#           preserve key order.
# ...

# %%
pd.merge(data,college,left_on="RollNumber",right_on='Roll Number')
# Out:
#              Timestamp                       Name  \
# 0  30/01/2020 15:00:39              B Jagan Mohan
# 1  30/01/2020 15:01:10               Harish Bandi
# 2  30/01/2020 15:01:24             Devendra Kumar
# 3  30/01/2020 15:02:49  JAYA NAVEEN KUMAR DUPPATI
#
#                         MailId                  Branch Qualification  \
# 0      bjaganmohan24@gmail.com            Data Science          M.sc
# 1      harishbandi12@gmail.com  Information Technology        B.TECH
# 2     devendra108148@gmail.com                     ECE        B.Tech
# 3  duppatijayanaveen@gmail.com                     I.T        B.TECH
#
#     Roll Number College  Year
# 0  121822502015    MVSR  2016
# 1    161FA07035  vignan  2020
# 2    14F41A0461     ASN  2018
# 3    161FA07012  vignan  2020

# %%
data
# Out:
#                         Timestamp                       Name  \
# RollNumber
# 161FA07039    30/01/2020 15:00:07              Sai Naga Raju
# 121722501019  30/01/2020 15:00:20                   R deepak
# 121722501015  30/01/2020 15:00:23              P K CHAITANYA
# 121722501002  30/01/2020 15:00:25                 B SRIKANTH
# 161fa04079    30/01/2020 15:00:28           Himaja cherukuri
# 161FA04180    30/01/2020 15:00:28              M.Geethanjali
# 161FA04106    30/01/2020 15:00:33                  M.Nikhita
# 161FA07042    30/01/2020 15:00:37           DASARI PAVAN SAI
# 121822502015  30/01/2020 15:00:39              B Jagan Mohan
# 121722501011  30/01/2020 15:00:41          k.parameswara rao
# 121822502017  30/01/2020 15:00:43           B.Ravindra kumar
# 121722501026  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 161FA07050    30/01/2020 15:00:45      Thatavarti kavya sree
# 161FA07035    30/01/2020 15:01:10               Harish Bandi
# ...

# %%
common_data.drop('Roll Number',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-2a597e9077f4> in <module>
# ----> 1 common_data.drop('Roll Number',axis=1,inplace=True)
#
# NameError: name 'common_data' is not defined

# %%
data.Timestamp
# Out:
# RollNumber
# 161FA07039      30/01/2020 15:00:07
# 121722501019    30/01/2020 15:00:20
# 121722501015    30/01/2020 15:00:23
# 121722501002    30/01/2020 15:00:25
# 161fa04079      30/01/2020 15:00:28
# 161FA04180      30/01/2020 15:00:28
# 161FA04106      30/01/2020 15:00:33
# 161FA07042      30/01/2020 15:00:37
# 121822502015    30/01/2020 15:00:39
# 121722501011    30/01/2020 15:00:41
# 121822502017    30/01/2020 15:00:43
# 121722501026    30/01/2020 15:00:44
# 161FA07050      30/01/2020 15:00:45
# 161FA07035      30/01/2020 15:01:10
# 121822502018    30/01/2020 15:01:16
# 14F41A0461      30/01/2020 15:01:24
# 161FA07002      30/01/2020 15:01:35
# 161FA07049      30/01/2020 15:01:49
# y167189053      30/01/2020 15:01:50
# 140082202030    30/01/2020 15:01:56
# 121722501013    30/01/2020 15:02:04
# 121822502016    30/01/2020 15:02:41
# 161FA07012      30/01/2020 15:02:49
# 133J1A0150      30/01/2020 15:02:59
# 161FA07025      30/01/2020 15:04:10
# ...

# %%
type(data.Timestamp[0])
# Out:
# str

# %%
pd.to_datetime(data.Timestamp)
# Out:
# RollNumber
# 161FA07039     2020-01-30 15:00:07
# 121722501019   2020-01-30 15:00:20
# 121722501015   2020-01-30 15:00:23
# 121722501002   2020-01-30 15:00:25
# 161fa04079     2020-01-30 15:00:28
# 161FA04180     2020-01-30 15:00:28
# 161FA04106     2020-01-30 15:00:33
# 161FA07042     2020-01-30 15:00:37
# 121822502015   2020-01-30 15:00:39
# 121722501011   2020-01-30 15:00:41
# 121822502017   2020-01-30 15:00:43
# 121722501026   2020-01-30 15:00:44
# 161FA07050     2020-01-30 15:00:45
# 161FA07035     2020-01-30 15:01:10
# 121822502018   2020-01-30 15:01:16
# 14F41A0461     2020-01-30 15:01:24
# 161FA07002     2020-01-30 15:01:35
# 161FA07049     2020-01-30 15:01:49
# y167189053     2020-01-30 15:01:50
# 140082202030   2020-01-30 15:01:56
# 121722501013   2020-01-30 15:02:04
# 121822502016   2020-01-30 15:02:41
# 161FA07012     2020-01-30 15:02:49
# 133J1A0150     2020-01-30 15:02:59
# 161FA07025     2020-01-30 15:04:10
# 245112769310   2020-01-30 15:07:38
# ...

# %%
data['Timestamp_dt'].dt.month
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Timestamp_dt'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-bf55cabefdf6> in <module>
# ----> 1 data['Timestamp_dt'].dt.month
#
# ...

# %%
data.Branch.value_counts()
# Out:
# Information Technology    4
# MCA                       4
# Data Science              3
# CSE                       2
# IT                        2
# I.T                       2
# Computer Science          2
# B.Sc(comp)                1
# b com(computers)          1
# cse                       1
# civil engineering         1
# Automobile Engineering    1
# DataScience               1
# ECE                       1
# Name: Branch, dtype: int64

# %%
data.Qualification.value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-74a89caff3e1> in <module>
# ----> 1 data.Qualification.value_count()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                         Timestamp                       Name  \
# RollNumber
# 161FA07039    30/01/2020 15:00:07              Sai Naga Raju
# 121722501019  30/01/2020 15:00:20                   R deepak
# 121722501015  30/01/2020 15:00:23              P K CHAITANYA
# 121722501002  30/01/2020 15:00:25                 B SRIKANTH
# 161fa04079    30/01/2020 15:00:28           Himaja cherukuri
# 161FA04180    30/01/2020 15:00:28              M.Geethanjali
# 161FA04106    30/01/2020 15:00:33                  M.Nikhita
# 161FA07042    30/01/2020 15:00:37           DASARI PAVAN SAI
# 121822502015  30/01/2020 15:00:39              B Jagan Mohan
# 121722501011  30/01/2020 15:00:41          k.parameswara rao
# 121822502017  30/01/2020 15:00:43           B.Ravindra kumar
# 121722501026  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 161FA07050    30/01/2020 15:00:45      Thatavarti kavya sree
# 161FA07035    30/01/2020 15:01:10               Harish Bandi
# ...

# %%
data.describe(include=object)
# Out:
#                   Timestamp              Name                  MailId  \
# count                    26                26                      26
# unique                   25                26                      26
# top     30/01/2020 15:00:28  B.Ravindra kumar  tvnagajyothi@gmail.com
# freq                      2                 1                       1
#
#                         Branch Qualification
# count                       26            26
# unique                      14            13
# top     Information Technology        B.Tech
# freq                         4             8

# %% [markdown]
# ### Sales data
# - Market Fact
# - cust Dimen
# - Product dimen
# - Order Dimensions
# - ship Dimensions

# %% [markdown]
# - Read the Market Fact data into market_df
# - Display the top five rows
# - Display the last three rows
# - Check the total number of entries you have
# - Check the No of features
# - Print features Names(Column Names)
# - Print the row indices of the dataframe
# - Check the dtype of each and every columns
# - Description for Numerical Column min,max,count,25%,50%,75%,std
# - Description for the categorical Columns count,top,freq
# - Missing value count column wise
# - Total Missing values count in the DataFrame
# - Check the output for the info function
# - Access 3,5,7 columns using iloc,loc and without using any of them
# - How many unique products are there
# - How amny unique customers are there
# - What is the maximum sales

# %%
data = pd.read_csv('https://raw.githubusercontent.com/sumathi16/Machine-Learning-with-Python/master/data/global_sales_data/market_fact.csv')
data
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
data.head(5)
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
data.tail(3)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.05      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.87      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.69      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8396              39  -70.85           5.35                 0.40
# 8397              23  565.34          30.00                 0.62
# 8398              47  131.39           4.86                 0.38

# %%
data.shape[0]
# Out:
# 8399

# %%
data.shape[1]
# Out:
# 10

# %%
data.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8399, step=1)

# %%
data.dtypes
# Out:
# Ord_id                  object
# Prod_id                 object
# Ship_id                 object
# Cust_id                 object
# Sales                  float64
# Discount               float64
# Order_Quantity           int64
# Profit                 float64
# Shipping_Cost          float64
# Product_Base_Margin    float64
# dtype: object

# %%
data.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000
