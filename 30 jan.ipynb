# %%
## to check the version
import pandas as pd
pd.__version__
# Out:
# '0.25.1'

# %%
import numpy as np
np.array([56,12,49])
# Out:
# array([56, 12, 49])

# %%
s = pd.Series([56,12,49],index=['raj','hari','sam'])
print(s[0],s['raj'])
# Out:
# 56 56

# %%
a = {'hari' : 56,'hello':15,'namesthe':17}
pd.Series(a)
# Out:
# hari        56
# hello       15
# namesthe    17
# dtype: int64

# %%
s.index
# Out:
# Index(['raj', 'hari', 'sam'], dtype='object')

# %%
d2 = {'name':[['hari','raju','sita'],
     'Langauge': ['py','c','r']]
     }
pd.DaraFrame(d2)
# Out:
#   File "<ipython-input-25-2562cc0eac09>", line 2
#     'Langauge': ['py','c','r']]
#               ^
# SyntaxError: invalid syntax

# %%
pd.DataFrame(d2,index=[423,415,100])
# Out:
#      name Langauge
# 423  hari       py
# 415  raju        c
# 100  sita        r

# %%
data = pd.read_csv('https://raw.githubusercontent.com/sumathi16/Machine-Learning-with-Python/master/data/Student%20Data%20ML%20Jan%20(Responses)%20-%20Form%20responses%201.csv')
data
# Out:
#               Timestamp                       Name  \
# 0   30/01/2020 15:00:07              Sai Naga Raju
# 1   30/01/2020 15:00:20                   R deepak
# 2   30/01/2020 15:00:23              P K CHAITANYA
# 3   30/01/2020 15:00:25                 B SRIKANTH
# 4   30/01/2020 15:00:28           Himaja cherukuri
# 5   30/01/2020 15:00:28              M.Geethanjali
# 6   30/01/2020 15:00:33                  M.Nikhita
# 7   30/01/2020 15:00:37           DASARI PAVAN SAI
# 8   30/01/2020 15:00:39              B Jagan Mohan
# 9   30/01/2020 15:00:41          k.parameswara rao
# 10  30/01/2020 15:00:43           B.Ravindra kumar
# 11  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 12  30/01/2020 15:00:45      Thatavarti kavya sree
# 13  30/01/2020 15:01:10               Harish Bandi
# 14  30/01/2020 15:01:16     M.Bhavani Sankar Reddy
# 15  30/01/2020 15:01:24             Devendra Kumar
# 16  30/01/2020 15:01:35                    M.Ramya
# ...

# %%
data.tail()
# Out:
#               Timestamp                       Name  \
# 21  30/01/2020 15:02:41           G. Vineeth Kumar
# 22  30/01/2020 15:02:49  JAYA NAVEEN KUMAR DUPPATI
# 23  30/01/2020 15:02:59                   vikram S
# 24  30/01/2020 15:04:10            SAI TEJA JALADI
# 25  30/01/2020 15:07:38         SAIKUMAR MANIKONDA
#
#                            MailId                  Branch Qualification  \
# 21          121822502016@gitam.in            Data Science          M.Sc
# 22    duppatijayanaveen@gmail.com                     I.T        B.TECH
# 23  vikramsabbavarapu60@gmail.com       civil engineering        B-tech
# 24    saitejajaladi2000@gmail.com                     I.T        B.TECH
# 25          saikumarm64@gmail.com  Automobile Engineering           B.E
#
#       RollNumber
# 21  121822502016
# 22    161FA07012
# 23    133J1A0150
# 24    161FA07025
# 25  245112769310

# %%
data.shape
# Out:
# (26, 6)

# %%
data.head(2)
# Out:
#              Timestamp           Name                            MailId  \
# 0  30/01/2020 15:00:07  Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 1  30/01/2020 15:00:20       R deepak            deepakrella9@gmail.com
#
#   Branch Qualification    RollNumber
# 0     IT        B.Tech    161FA07039
# 1    MCA            PG  121722501019

# %%
data['Name']
# Out:
# 0                 Sai Naga Raju
# 1                      R deepak
# 2                 P K CHAITANYA
# 3                    B SRIKANTH
# 4              Himaja cherukuri
# 5                 M.Geethanjali
# 6                     M.Nikhita
# 7              DASARI PAVAN SAI
# 8                 B Jagan Mohan
# 9             k.parameswara rao
# 10             B.Ravindra kumar
# 11          P.M.S.Bhargav Kumar
# 12        Thatavarti kavya sree
# 13                 Harish Bandi
# 14       M.Bhavani Sankar Reddy
# 15               Devendra Kumar
# 16                      M.Ramya
# 17              T.V.Naga Jyothi
# 18               Ananda Lakshmi
# 19                  K . krishna
# 20         Md.Ali Asghar Khoyee
# 21             G. Vineeth Kumar
# 22    JAYA NAVEEN KUMAR DUPPATI
# 23                     vikram S
# 24              SAI TEJA JALADI
# 25           SAIKUMAR MANIKONDA
# Name: Name, dtype: object

# %%
data[['Name','MailId']]
type(data['Name'])
# Out:
# pandas.core.series.Series

# %%
data.sample()
# Out:
#               Timestamp             Name                       MailId Branch  \
# 24  30/01/2020 15:04:10  SAI TEJA JALADI  saitejajaladi2000@gmail.com    I.T
#
#    Qualification  RollNumber
# 24        B.TECH  161FA07025

# %%
data.isnull()
# Out:
#     Timestamp   Name  MailId  Branch  Qualification  RollNumber
# 0       False  False   False   False          False       False
# 1       False  False   False   False          False       False
# 2       False  False   False   False          False       False
# 3       False  False   False   False          False       False
# 4       False  False   False   False          False       False
# 5       False  False   False   False          False       False
# 6       False  False   False   False          False       False
# 7       False  False   False   False          False       False
# 8       False  False   False   False          False       False
# 9       False  False   False   False          False       False
# 10      False  False   False   False          False       False
# 11      False  False   False   False          False       False
# 12      False  False   False   False          False       False
# 13      False  False   False   False          False       False
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
print(True + False)
print(True + True)
print(False + False)
print(False + True)
# Out:
# 1
# 2
# 0
# 1

# %%
data = pd.read_tsv('https://raw.githubusercontent.com/sumathi16/Machine-Learning-with-Python/master/data/Student%20Data%20ML%20Jan%20(Responses)%20-%20Form%20responses%201.tsv')
data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-7aa3b1fa0a8e> in <module>
# ----> 1 data = pd.read_tsv('https://raw.githubusercontent.com/sumathi16/Machine-Learning-with-Python/master/data/Student%20Data%20ML%20Jan%20(Responses)%20-%20Form%20responses%201.tsv')
#       2 data
#
# ~\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'read_tsv'

# %%
data.iloc[0]
# Out:
# Timestamp                     30/01/2020 15:00:07
# Name                                Sai Naga Raju
# MailId           sainagarajusakhamuri99@gmail.com
# Branch                                         IT
# Qualification                              B.Tech
# RollNumber                             161FA07039
# Name: 0, dtype: object

# %%
data.iloc[0:1]
# Out:
#              Timestamp           Name                            MailId  \
# 0  30/01/2020 15:00:07  Sai Naga Raju  sainagarajusakhamuri99@gmail.com
#
#   Branch Qualification  RollNumber
# 0     IT        B.Tech  161FA07039

# %%
data.iloc[0:6:2]
# Out:
#              Timestamp              Name                            MailId  \
# 0  30/01/2020 15:00:07     Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 2  30/01/2020 15:00:23     P K CHAITANYA              chaitu1495@gmail.com
# 4  30/01/2020 15:00:28  Himaja cherukuri         himajacherukuri@gmail.com
#
#   Branch Qualification    RollNumber
# 0     IT        B.Tech    161FA07039
# 2    MCA            PG  121722501015
# 4    cse         BTech    161fa04079

# %%
data.iloc[0:6:2,1:3]
# Out:
#                Name                            MailId
# 0     Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 2     P K CHAITANYA              chaitu1495@gmail.com
# 4  Himaja cherukuri         himajacherukuri@gmail.com

# %%
data.iloc[-2:]
# Out:
#               Timestamp                Name                       MailId  \
# 24  30/01/2020 15:04:10     SAI TEJA JALADI  saitejajaladi2000@gmail.com
# 25  30/01/2020 15:07:38  SAIKUMAR MANIKONDA        saikumarm64@gmail.com
#
#                     Branch Qualification    RollNumber
# 24                     I.T        B.TECH    161FA07025
# 25  Automobile Engineering           B.E  245112769310

# %%
data.loc[0:4:2,'Name','Mailld']
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-9-f3d22e31c766> in <module>
# ----> 1 data.loc[0:4:2,'Name','Mailld']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     808
#     809         # no multi-index, so validate all of the indexers
# --> 810         self._has_valid_tuple(tup)
#     811
#     812         # ugly hack for GH #836
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     231         for i, k in enumerate(key):
# ...

# %%
import re
for i in data["MailId"]:
    if not re.search(".@gmail.com",i):
        print(i)
# Out:
# 121822502016@gitam.in
